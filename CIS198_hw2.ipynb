# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiadavis14/cis198first/blob/main/CIS198_hw2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a function in python always has a set of parenthesis following the funtion name. In the parenthesis put your function inputs aka ***parameters***.

# %%
print ('hello world')
# Out:
# hello world

# %% [markdown]
# ## Creating a poem with ChatGPT
#
# Here is our prompt:
#
# create rhyming song lyrics about a Niagara university computer science class called Intro the Computer Education with students Sofia, Andrew, Hannah, Julian, Joe, Cue, and Professor Ty. They study programming, office applications, creating websites, admin perspectives of educational platforms, google slides, but they don't over iPhone. Mention the school mascot Monte the purple eagle, mention the school closing for snow says. Sofia has awesome roomates name Bre, Tine, and Paige. Have it fun and humorous!
#
# Here is the output I got:
#
# [🎶 Intro to Computer Education (Niagara Jam) 🎶]
# [Verse 1]
# In Intro to Computer Education, log in, take a seat,
# Sofia, Andrew, Hannah—yeah, this class is kinda sweet.
# Julian, Joe, and Cue, typing lines of code,
# With Professor Ty in charge, saying “Trust the process, mode!”
# [Pre-Chorus]
# We’re programming, debugging, watching errors disappear,
# “If it compiles, we celebrate!” is basically our cheer.
# [Chorus]
# Monte the Purple Eagle flying high above the scene,
# Niagara Uni pride, purple, bold, and mean (but clean).
# We build websites, slides, and apps for education—
# But don’t ask us about iPhones… that’s not the situation! 📵
# [Verse 2]
# We master Office apps like it’s a superpower grind,
# Spreadsheets, docs, and slides blowing academic minds.
# Google Slides looking slick, transitions on parade,
# Admin views of learning platforms—decisions gotta be made!
# [Pre-Chorus 2]
# Backend, frontend, teacher admin sight,
# Who knew education tech could feel this tight?
# Chorus
# Monte the Purple Eagle, flap those wings of pride,
# Snow day alert! Campus closed—let it slide ❄️
# From coding late to checking snow day says,
# Niagara weather running our academic ways.
# [Bridge (Sofia Feature 😄)]
# Sofia’s got roommates—Bre, Tina, and Paige,
# That apartment’s pure chaos (in a wholesome way).
# Late-night laughs, group chats explode,
# “Who took my charger?”—classic roommate code.
# [Verse 3]
# Professor Ty says, “Think like admins do,”
# Platforms, users, access—yeah, the big picture too.
# Education meets tech, and somehow it works,
# Even when the software’s got… personality quirks.
# [Final Chorus]
# Monte the Purple Eagle, Niagara through and through,
# Intro to Computer Ed—yeah, we know a thing or two.
# We code, we click, we laugh, we persevere,
# Just don’t ask us about iPhones… we made that clear!
# [🎶 End on a snow day fade-out… 🎶]

# %% [markdown]
# ### Markdown Basics
# -------------------
# ***end a line with two spaces to create a new line***
# *italic*.
# **bold**.
#
# Bulleted List:
# * I
# * Like
# * Computers
#
# Numbered List
# 1. Welcome
# 1. to
# 1. Niagara
# 1. University

# %% [markdown]
# **How to make a Table**
# |Name|*Major*|
# |-------:|:-------|
# |Monte|*Computer Science*|
# |Father Maher|Theology|

# %% [markdown]
# #### Links
# [My University](https://www.niagara.edu).

# %% [markdown]
# %%HTML
# <p style="font=size: 50px;">Hello World in Big Font</p>

# %%
# %%HTML
# <p style="font-size: 50px;">Hello World in Big Font</p>
# Out:
# <p style="font-size: 50px;">Hello World in Big Font</p>
