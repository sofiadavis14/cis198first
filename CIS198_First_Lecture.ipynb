# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiadavis14/cis198first/blob/main/CIS198_First_Lecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basic Colab Notes
#
# * Colab uses interactive python notebooks (.ipynb files).
# * A notebook is made of a vertical stact of cells.
# * There are two cell types:
#   1. Code - python
#   1. Text - raw text, markdown or html
#
# *markdown* - is a simple "markup language" that allows you to do formatting but is still readable in its raw text form
# ### Examples of markdown
#
# *bold text*
# **italic text**
#
# [The Best University on Earth](http://niagara.edu)

# %%
# This is a python comment
# code comments gets ignored when the program is run
print('Hello World')
# Out:
# Hello World
